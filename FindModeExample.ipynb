# %%
import numpy as np
from sklearn.cluster import MeanShift, estimate_bandwidth
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt

# %%
from find_mode import find_max_mode, find_max_mode2

# %%
find_max_mode(
    means=np.array([[0, 0], [1, 1], [0, 1]]),
    cov=0.1,
    sample_size=10000,
    verbose=True,
    quantile=0.1
)
# Out:
# Sampling...
# Estimating bandwith...
# Fitting MeanShift...
# array([0.03612371, 0.97442726])

# %%
find_max_mode(
    means=np.array([[0, 0], [1, 1], [0, 1]]),
    cov=1,
    sample_size=10000,
    verbose=True,
    quantile=0.1
)
# Out:
# Sampling...
# Estimating bandwith...
# Fitting MeanShift...
# array([0.33718639, 0.70265564])

# %%
find_max_mode(
    means=np.vstack((np.zeros(50), np.ones(50))),
    cov=0.1,
    sample_size=10000,
    verbose=True,
    quantile=0.1
)
# Out:
# Sampling...
# Estimating bandwith...
# Fitting MeanShift...
# array([-0.00335791, -0.00091943,  0.00369675, -0.00575361, -0.00241859,
#        -0.00179743,  0.00186952, -0.0002399 , -0.00182353, -0.00086209,
#        -0.00387183, -0.00235852,  0.00539552,  0.00017564,  0.00053903,
#         0.00464186, -0.00563339, -0.00433259,  0.00035116,  0.00163324,
#         0.00822286,  0.00097206,  0.00647189,  0.00415187,  0.00013642,
#         0.00067794, -0.00543857,  0.00026653,  0.00063044,  0.00258699,
#        -0.00208834,  0.00100412,  0.00205356, -0.00421953, -0.00188662,
#         0.00362576,  0.0002275 ,  0.00196576,  0.00200527, -0.00118509,
#        -0.00062482,  0.0109386 , -0.0022452 , -0.00276267, -0.00303644,
#         0.00331699,  0.00038723, -0.00168851,  0.00109233, -0.0018092 ])

# %%
find_max_mode2(
    means=np.vstack((np.zeros(50), np.ones(50))),
    cov=0.1,
    sample_size=10000,
    verbose=True
)
# Out:
# Sampling...
# Searching...
